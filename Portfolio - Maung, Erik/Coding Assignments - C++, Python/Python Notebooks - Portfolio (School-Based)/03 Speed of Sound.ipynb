# %% [markdown]
# Import Setup

# %%
import numpy as np
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/gdrive')

dis10 = np.loadtxt('/content/gdrive/MyDrive/2021-2022/22Winter/4AL/Python References/1.13 Speed of Sound/10cm.csv')
dis15 = np.loadtxt('/content/gdrive/MyDrive/2021-2022/22Winter/4AL/Python References/1.13 Speed of Sound/15cm.csv')
dis20 = np.loadtxt('/content/gdrive/MyDrive/2021-2022/22Winter/4AL/Python References/1.13 Speed of Sound/20cm.csv')
dis25 = np.loadtxt('/content/gdrive/MyDrive/2021-2022/22Winter/4AL/Python References/1.13 Speed of Sound/25cm.csv')
dis30 = np.loadtxt('/content/gdrive/MyDrive/2021-2022/22Winter/4AL/Python References/1.13 Speed of Sound/30cm.csv')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Array Setup

# %%
distancex = np.array([0.1,0.15,0.2,0.25,0.3])
timey = np.array([np.mean(dis10), np.mean(dis15), np.mean(dis20), np.mean(dis25), np.mean(dis30)])
print(distancex)
print(timey)
# Out:
# [0.1  0.15 0.2  0.25 0.3 ]
# [ 557.23  883.54 1118.55 1422.61 1692.51]
