# %%
#TO FILL
#Recreate the same histogram but with 20 bins instead of 5 bins
#Here is the documentation for plt.hist : https://matplotlib.org/3.3.3/api/_as_gen/matplotlib.pyplot.hist.html
plt.hist(samples, bins = 20)
# Out:
# (array([  1.,   7.,   4.,  14.,  41.,  62.,  80.,  94., 126., 126., 111.,
#         103.,  82.,  75.,  37.,  18.,  10.,   4.,   3.,   2.]),
#  array([-1.19842167,  0.47305058,  2.14452283,  3.81599508,  5.48746733,
#          7.15893958,  8.83041183, 10.50188408, 12.17335633, 13.84482858,
#         15.51630083, 17.18777308, 18.85924533, 20.53071758, 22.20218983,
#         23.87366208, 25.54513433, 27.21660658, 28.88807883, 30.55955108,
#         32.23102333]),
#  <a list of 20 Patch objects>)

# %%
#TO FILL
#Print the mean of the variable samples - use np.mean
#Print the standard deviation of the variablre samples - use np.std
print(str(np.mean(samples)))
print(str(np.std(samples)))
# Out:
# 10.041110955293334
# 6.02927149094637

# %%
import numpy as np
# reaction times abbreviated as rt
rtlarge = np.array([0.324, 0.325, 0.333, 0.319, 0.303, 0.304, 0.304, 0.321, 0.317, 0.311, 0.338, 0.326, 0.299, 0.33, 0.305, 0.314])
rtsmall = np.array([0.294, 0.295, 0.298, 0.296])
print('The mean of the 16-data set is ' + str(np.around(np.mean(rtlarge),3)) + '.')
print('The mean of the 4-data set is ' + str(np.around(np.mean(rtsmall),3)) + '.')
print('The st. dev. of the 16-data set is ' + str(np.around(np.std(rtlarge),3)) + '.')
print('The st. dev. of the 4-data set is ' + str(np.around(np.std(rtsmall),3)) + '.')
# Out:
# The mean of the 16-data set is 0.317.
# The mean of the 4-data set is 0.296.
# The st. dev. of the 16-data set is 0.012.
# The st. dev. of the 4-data set is 0.001.
